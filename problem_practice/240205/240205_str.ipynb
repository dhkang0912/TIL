# %% [markdown]
# ## 문자열 (string)
# ### 컴퓨터에서의 문자 표현
# - 각 문제에 대응하는 숫자를 저장해놓고 이것을 메모리에 저장함
# - 영어가 대소문자 합쳐서 52자이므로 6(64)비트면 모두 표현할 수 있음
#     - 이를 코드 체계라고 함   <br>  <br>
# - 확장 아스키는 표준 문자 이외에 여러 다양한 문자를 추가하여 쓸 수 있는 부호 (128개)
# - 오늘 날 대부분의 컴퓨터는 문자를 쓰는데 ASCII형식을 사용함
# - 유니코드도 character set으로 분류됨

# %% [markdown]
# ### 유니코드 인코딩
# - UTF - 8
#     - MIN : 8bit
# - UTF - 16
#     - MIN : 16bit
# - UTF - 32  (in unix)
#     - MIN : 32bit

# %%
# a = '1' #문자열
# a = 1
#
# 문자열 저장하는데 가장 오래된 방식이 아스키 문자
# 대부분의 언어에서는 숫자를 넣으면 문자로 뽑아내는 코드가 정해져있음
#
# a = ord('1')
# print(a) #49
#
# 0 > 16진수 30 > 10진수 48
# A > 16진수 41(4하나) > 10진수 65
#
# 'f' > 'F'
# a = ord('f') - ord('a') + ord('A') #70
# print(chr(a)) #F
#
# 문자열 뒤집기
# s = "abcdef test"
#
# new_s = s[::-1]
# print(new_s)
#
# result = ''
# for idx in range(len(s)-1, -1, -1) :
#     c = s[idx]
#     result = result +c
# print(result)
#
# N = len(s)
# l_s = list(s)
# for i in range(len(s)//2) :
#     # s[i], s[N-1-i] = s[n-1-i], s[i] # 문자열 불변이기 때문에 일부만 바꾸려면 리스트 형태로 바꿔서 인덱스 교환 후 조인으로 합치기
#     l_s[i], l_s[N - 1 - i] = l_s[n - 1 - i], l_s[i]
#     ''.join(l_s)
#
# l_s = list(s)
# l_s.reverse() # 자체값 바꾸고 리턴값 없음(불변일 경우 반드시 리턴값 사용-문자열)
# print(''.join(l_s))
#
#
# def atoi(s) : #문자열을 숫자로 바꾸는데 사용/'123' > 123 타입 바꿔줌
#     r = 0
#     for c in s :
#         r = r*10 + (ord(c)-ord('0')) #0으로부터의 간격 구해서 빼기
#     return r
#
#     # return int(s) # 파이썬으로 구하는 방법
#     # 풀이
#         #c ='1'
#         #r > 1
#         #r = r*10 +2 > 12
#         #r = r*10 +3 > 123
#
# t = atoi('123')
# print(t, type(t))
#
#
# def itoa(number) : #321 > '321'
#     while number > 0 :
#         # c = chr(48 + number % 10) # 0은 아스키코드 48
#         c = chr(ord('0') + number % 10)
#         result = c + result
#         number = number // 10
#     return result
#     # 풀이
#         #n = 321
#         #321 % 10 > 1
#         #32 % 10 > 2
#         #3 % 10 > 3
# t = itoa(321)
# print(t, type(t))
#
# a = 'aa'
# b = 'ab'
# print(a>b) #False

# a = 'aa'
# b = 'a'
# print(a>b) #True

# a = 'bc'
# b = 'a'
# print(a>b) #True
